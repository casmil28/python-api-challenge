# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import numpy as np
import matplotlib.pyplot as plt

# Import API key
from api_keys import geoapify_key
print(geoapify_key)
# Out:
# 66b3411fc8954138bef241a91a56abdd

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0          vorgashor  67.5833   63.9500    275.26        96
# 1        1      blackmans bay -43.0167  147.3167    277.89        86
# 2        2  port-aux-francais -49.3500   70.2167    278.18        95
# 3        3            talnakh  69.4865   88.3972    276.60        98
# 4        4            dudinka  69.4058   86.1778    276.86        94
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        3.36      RU  1717968397
# 1           7        0.89      AU  1717968397
# 2         100       15.31      TF  1717968397
# 3         100        1.72      RU  1717968397
# 4         100        3.58      RU  1717968397

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
humidity = city_data_df["Humidity"].astype(int)

map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color="City",
    alpha=.75
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Convert temperature from Kelvin to Celsius
city_data_df["Max Temp (C)"] = city_data_df["Max Temp"] - 273.15

# Check the converted temperatures
print(city_data_df[["Max Temp", "Max Temp (C)"]].head())

# Narrow down cities that fit criteria and drop any results with null values
narrowed_city_data_df = city_data_df.loc[
    (city_data_df["Max Temp (C)"] < 50) & (city_data_df["Max Temp (C)"] > 15) \
    & (city_data_df["Wind Speed"] < 6.0) \
    & (city_data_df["Cloudiness"] == 0)
]

narrowed_city_data_df = narrowed_city_data_df.dropna()

# Display sample data
narrowed_city_data_df
# Out:
#    Max Temp  Max Temp (C)
# 0    275.26          2.11
# 1    277.89          4.74
# 2    278.18          5.03
# 3    276.60          3.45
# 4    276.86          3.71
#      City_ID                        City      Lat       Lng  Max Temp  \
# 41        41           wailua homesteads  22.0669 -159.3780    301.39
# 103      103                    tomatlan  19.9333 -105.2500    304.42
# 108      108                       lihue  21.9789 -159.3672    301.73
# 111      111              estacion bamoa  25.7081 -108.3115    310.74
# 114      114                     tortoli  39.9256    9.6572    297.05
# 117      117                saint-pierre -21.3393   55.4781    294.97
# 131      131                       chios  38.3678   26.1358    302.07
# 142      142                  al qusiyah  27.4402   30.8184    303.26
# 148      148                   al bayda'  32.7627   21.7551    292.15
# 181      181  san sebastian de la gomera  28.0916  -17.1133    295.58
# 191      191                    douentza  14.9951   -2.9517    311.46
# 205      205                  clearwater  27.9659  -82.8001    308.24
# 207      207                        idri  27.5000   13.2667    303.12
# 215      215           fort myers shores  26.7092  -81.7459    308.18
# 227      227                   ierapetra  35.0100   25.7353    300.45
# 254      254      hawaiian paradise park  19.5933 -154.9731    300.88
# 266      266           port saint john's -31.6229   29.5448    289.40
# 291      291                 east london -33.0153   27.9116    288.76
# 293      293                       khost  33.3395   69.9204    297.08
# 312      312                 al burayqah  30.4062   19.5739    296.71
# 313      313                 port alfred -33.5906   26.8910    289.01
# 335      335                 turkmenbasy  40.0222   52.9552    298.58
# 341      341            puerto maldonado -12.6000  -69.1833    305.37
# 360      360    sao gabriel da cachoeira  -0.1303  -67.0892    301.04
# 374      374                  stara tura  48.7772   17.6943    292.53
# 395      395                     gonabad  34.3529   58.6837    299.03
# 403      403                   petrolina  -9.3986  -40.5008    303.18
# 416      416                      kapa'a  22.0752 -159.3190    302.14
# 421      421                    timbuktu  16.7735   -3.0074    311.89
# 422      422                   wenatchee  47.4235 -120.3103    302.86
# 431      431              agios nikolaos  35.1914   25.7133    300.24
# 432      432                     zamania  25.4333   83.5667    308.55
# 442      442                        bodo  67.2800   14.4050    288.68
# 444      444                 al kharijah  25.4514   30.5464    303.49
# 446      446                      rampur  28.8167   79.0333    304.39
# 449      449                       datca  36.7378   27.6842    299.12
# 459      459                   prymors'k  46.7348   36.3443    294.31
# 468      468                       demre  36.2537   29.9777    297.91
# 480      480                    ad dilam  23.9915   47.1627    308.38
# 489      489                       tabas  33.5959   56.9244    302.27
# 537      537                 saint-denis  48.9167    2.3333    289.23
# 539      539                        hilo  19.7297 -155.0900    301.00
# 542      542                maydanshakhr  34.3956   68.8662    288.35
#
#      Humidity  Cloudiness  Wind Speed Country        Date  Max Temp (C)
# 41         73           0        5.66      US  1717968402         28.24
# 103        46           0        5.47      MX  1717968410         31.27
# 108        66           0        5.66      US  1717968410         28.58
# 111        34           0        5.87      MX  1717968411         37.59
# 114        64           0        3.60      IT  1717968411         23.90
# 117        73           0        1.54      RE  1717968411         21.82
# 131        21           0        2.06      GR  1717968413         28.92
# 142        20           0        3.96      EG  1717968415         30.11
# 148        52           0        0.56      LY  1717968415         19.00
# 181        78           0        0.51      ES  1717968419         22.43
# 191        22           0        1.32      ML  1717968421         38.31
# 205        63           0        4.63      US  1717968126         35.09
# 207        12           0        3.33      LY  1717968423         29.97
# 215        57           0        4.12      US  1717968424         35.03
# 227        33           0        3.58      GR  1717968425         27.30
# 254        64           0        3.09      US  1717968429         27.73
# 266        66           0        2.53      ZA  1717968430         16.25
# 291        68           0        2.55      ZA  1717968434         15.61
# 293        36           0        1.16      AF  1717968434         23.93
# 312        66           0        3.20      LY  1717968436         23.56
# 313        63           0        3.66      ZA  1717968437         15.86
# 335        47           0        3.09      TM  1717968440         25.43
# 341        55           0        2.06      PE  1717968440         32.22
# 360        83           0        1.03      BR  1717968442         27.89
# 374        91           0        4.12      SK  1717968444         19.38
# 395        17           0        2.34      IR  1717968448         25.88
# 403        42           0        4.63      BR  1717968449         30.03
# 416        73           0        5.66      US  1717968451         28.99
# 421        16           0        2.94      ML  1717968452         38.74
# 422        38           0        2.57      US  1717968393         29.71
# 431        33           0        3.14      GR  1717968453         27.09
# 432        18           0        2.79      IN  1717968453         35.40
# 442        54           0        2.57      NO  1717968454         15.53
# 444        17           0        3.71      EG  1717968454         30.34
# 446        16           0        3.47      IN  1717968455         31.24
# 449        74           0        2.93      TR  1717968455         25.97
# 459        68           0        2.94      UA  1717968456         21.16
# 468        46           0        1.91      TR  1717968457         24.76
# 480        11           0        3.04      SA  1717968459         35.23
# 489        12           0        2.06      IR  1717968460         29.12
# 537        51           0        4.12      FR  1717968360         16.08
# 539        65           0        3.09      US  1717968468         27.85
# 542        46           0        1.62      AF  1717968468         15.20

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df.head()
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 0          vorgashor      RU  67.5833   63.9500        96
# 1      blackmans bay      AU -43.0167  147.3167        86
# 2  port-aux-francais      TF -49.3500   70.2167        95
# 3            talnakh      RU  69.4865   88.3972        98
# 4            dudinka      RU  69.4058   86.1778        94

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
import requests

# Set the parameters to search for a hotel
radius = 10000  # Radius in meters
params = {
    "categories": "accommodation.hotel",
    "apiKey": geoapify_key,
    "limit": 1
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make an API request using the params dictionary
    response = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    places = response.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = places["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df.head()
# Out:
# Starting hotel search
# vorgashor - nearest hotel: София
# blackmans bay - nearest hotel: Villa Howden
# port-aux-francais - nearest hotel: Keravel
# talnakh - nearest hotel: Талнах
# dudinka - nearest hotel: Виктория
# fort mcmurray - nearest hotel: Nomad Hotel and Suites
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# nueva palestina - nearest hotel: No hotel found
# isafjordur - nearest hotel: Hótel Horn
# nadi - nearest hotel: President Hotel
# college - nearest hotel: BEST WESTERN PLUS Pioneer Park Inn
# eirunepe - nearest hotel: No hotel found
# ushuaia - nearest hotel: Apart Hotel Aires del Beagle
# igarka - nearest hotel: Заполярье
# bilibino - nearest hotel: No hotel found
# bethel - nearest hotel: Hampton Inn Danbury
# la passe - nearest hotel: L'Estuaire
# vilyuchinsk - nearest hotel: Победа
# wingham - nearest hotel: No hotel found
# papatowai - nearest hotel: No hotel found
# mahibadhoo - nearest hotel: No hotel found
# iskateley - nearest hotel: Авантаж
# belev - nearest hotel: Ока
# hamilton - nearest hotel: North Vista Manor
# nyuzen - nearest hotel: Mark Hotel マークホテル
# bredasdorp - nearest hotel: Victoria Hotel
# castillos - nearest hotel: A mi gente
# lovington - nearest hotel: Comfort Inn & Suites
# tongliao - nearest hotel: No hotel found
# brisas de zicatela - nearest hotel: Casa de Olas
# albany - nearest hotel: No hotel found
# cabo san lucas - nearest hotel: Comfort Rooms
# tazacorte - nearest hotel: App Leyma
# hajjah - nearest hotel: فندق السويدي
# las heras - nearest hotel: Posadas del Sur
# quelimane - nearest hotel: Mabassa
# wynyard - nearest hotel: Wynyard Hotel
# punta arenas - nearest hotel: Hotel Lacolet
# magadan - nearest hotel: Гостиница «ВМ-Центр»
# grytviken - nearest hotel: No hotel found
# springbok - nearest hotel: Elkoweru Guesthouse
# wailua homesteads - nearest hotel: Hilton Garden Inn Kauai Wailua Bay
# carnarvon - nearest hotel: No hotel found
# pimentel - nearest hotel: Hospedaje Calle del Sol
# waitangi - nearest hotel: Hotel Chathams
# salahonda - nearest hotel: No hotel found
# tolanaro - nearest hotel: Hôtel Mahavokey
# yellowknife - nearest hotel: No hotel found
# longyearbyen - nearest hotel: The Vault
# olonkinbyen - nearest hotel: No hotel found
# todos santos - nearest hotel: Hotel Casa Tota
# san antonio de pale - nearest hotel: No hotel found
# arraial do cabo - nearest hotel: No hotel found
# adamstown - nearest hotel: No hotel found
# edinburgh of the seven seas - nearest hotel: No hotel found
# tobol'sk - nearest hotel: Ямская
# katsuren-haebaru - nearest hotel: No hotel found
# angostura - nearest hotel: No hotel found
# saldanha - nearest hotel: Hoedjesbaai
# whitehorse - nearest hotel: Town & Mountain Hotel
# fort bragg - nearest hotel: Airborne Inn Lodging
# anahuac - nearest hotel: Hotel Anáhuac
# dauphin - nearest hotel: No hotel found
# murghob - nearest hotel: Pamir Hotel
# puerto ayora - nearest hotel: Hostal La Mirada De Solitario George
# invercargill - nearest hotel: The Grand
# puerto san jose - nearest hotel: Martita
# mogocha - nearest hotel: 7Ka
# inhambane - nearest hotel: Hotel de Inhambane
# san luis de la loma - nearest hotel: No hotel found
# red hill - nearest hotel: No hotel found
# acapulco de juarez - nearest hotel: Hotel del Valle
# nar'yan-mar - nearest hotel: Гостиница "Агат"
# al ghayzah - nearest hotel: فندق تاج العرب
# puerto natales - nearest hotel: Dorotea Patagonia Hostel
# jamestown - nearest hotel: DoubleTree Jamestown
# westport - nearest hotel: Norwalk Inn and Conference Center
# smithers - nearest hotel: Sunshine Inn Hotel
# san julian - nearest hotel: No hotel found
# sol'-iletsk - nearest hotel: Konnov hotel
# dogondoutchi - nearest hotel: Maison Alheri
# touros - nearest hotel: Pousada Atlântico
# ketchikan - nearest hotel: Cape Fox Lodge
# ezequiel montes - nearest hotel: Hotel La Capilla
# jabor - nearest hotel: No hotel found
# keflavik - nearest hotel: Núpan Deluxe
# stanley - nearest hotel: Hotel 52
# thompson - nearest hotel: Thompson Inn
# kailua-kona - nearest hotel: Kona Seaside Hotel
# calingasta - nearest hotel: Nora Hôtel
# booue - nearest hotel: La splendeur de l'équateur
# coahuayana de hidalgo - nearest hotel: No hotel found
# ilulissat - nearest hotel: Best Western Plus Hotel Ilulissat
# taksimo - nearest hotel: No hotel found
# kidal - nearest hotel: No hotel found
# tiksi - nearest hotel: Арктика
# gorontalo - nearest hotel: Grand City Hotel
# maceio - nearest hotel: Maceió Hostel e Pousada
# konarka - nearest hotel: Hotel Sun Village
# guerrero negro - nearest hotel: Plaza sal paraiso
# hithadhoo - nearest hotel: Pebbles Inn
# taroa - nearest hotel: No hotel found
# ribeira grande - nearest hotel: Hospedaria JSF
# tomatlan - nearest hotel: Hotel Hacienda Vieja Tomatlan
# cartagena - nearest hotel: Hotel Bellamar
# sault ste. marie - nearest hotel: Holiday Inn
# badger - nearest hotel: Clarion Hotel & Suites
# potosi - nearest hotel: Hotel Tarija
# lihue - nearest hotel: Kauai Palms
# kerikeri - nearest hotel: Avalon Resort
# avarua - nearest hotel: Paradise Inn
# estacion bamoa - nearest hotel: No hotel found
# lubango - nearest hotel: Novo Hotel
# kununurra - nearest hotel: No hotel found
# tortoli - nearest hotel: La Corte
# berdigestyakh - nearest hotel: No hotel found
# taounate - nearest hotel: No hotel found
# saint-pierre - nearest hotel: Tropic Hotel
# kavaratti - nearest hotel: No hotel found
# kruisfontein - nearest hotel: No hotel found
# udachny - nearest hotel: Вилюй
# itoman - nearest hotel: No hotel found
# ust-nera - nearest hotel: гостиница "Солнечная"
# port mathurin - nearest hotel: Escale Vacances
# san pedro de macoris - nearest hotel: No hotel found
# kharp - nearest hotel: Собь
# alindao - nearest hotel: No hotel found
# hermanus - nearest hotel: Aloe guest house
# manggar - nearest hotel: No hotel found
# quellon - nearest hotel: Aliwen
# qaqortoq - nearest hotel: Hotel Qaqortoq
# chios - nearest hotel: Aegean Sea
# biysk - nearest hotel: Гостиница "Центральная"
# bim son - nearest hotel: Thăng Long Hotel
# kennesaw - nearest hotel: SpringHill Suites Atlanta Kennesaw
# anadyr - nearest hotel: Гостевой дом
# vila velha - nearest hotel: Hotel Prainha
# melekeok village - nearest hotel: No hotel found
# floro - nearest hotel: Comfort Hotel Victoria Florø
# chibougamau - nearest hotel: No hotel found
# truckee - nearest hotel: The Truckee Hotel
# uturoa - nearest hotel: Hawaiki Nui hotel
# al qusiyah - nearest hotel: No hotel found
# antsiranana - nearest hotel: Central
# west island - nearest hotel: Cocos Village Bungalows
# maua - nearest hotel: Go Inn Santo André
# el fasher - nearest hotel: Noor Aleman
# lincheng - nearest hotel: 小城之春假日酒店
# al bayda' - nearest hotel: فندق الهديل
# darasun - nearest hotel: No hotel found
# rio grande - nearest hotel: Hotel Vila Moura Executivo
# bonthe - nearest hotel: No hotel found
# okhotsk - nearest hotel: No hotel found
# margaret river - nearest hotel: Margaret River Hotel
# georgetown - nearest hotel: Page 63 hostel
# palmdale - nearest hotel: No hotel found
# iqaluit - nearest hotel: Frobisher Inn
# sinan - nearest hotel: No hotel found
# alice springs - nearest hotel: Aurora Alice Springs
# haiku-pauwela - nearest hotel: Inn At Mama's Fish House
# san patricio - nearest hotel: No hotel found
# bangassou - nearest hotel: Hotel De Tourisme
# sitka - nearest hotel: Aspen Suites Hotel
# callao - nearest hotel: Casa Ronald
# yangambi - nearest hotel: No hotel found
# kajaani - nearest hotel: Original Sokos Hotel Valjus
# mugia - nearest hotel: Solpor do Coído
# sinabang - nearest hotel: No hotel found
# puerto lopez - nearest hotel: Bucarica
# auki - nearest hotel: No hotel found
# codrington - nearest hotel: No hotel found
# benjamin aceval - nearest hotel: No hotel found
# alofi - nearest hotel: Matavai Resort
# aix-les-bains - nearest hotel: Hôtel des Bains
# tralee - nearest hotel: The Ashe Hotel
# puerto aysen - nearest hotel: Hostal Dendal
# taishan - nearest hotel: 天诚港大酒店
# barcelos - nearest hotel: Hotel Dom Nuno
# utrik - nearest hotel: No hotel found
# fortuna - nearest hotel: Comfort Inn & Suites Redwood Country
# boyolangu - nearest hotel: Crown Victoria
# san sebastian de la gomera - nearest hotel: Hotel Villa Gomera
# rongelap - nearest hotel: No hotel found
# yelizovo - nearest hotel: Николина Усадьба
# dom pedro - nearest hotel: No hotel found
# porto novo - nearest hotel: Hôtel 6500 CFA
# port moresby - nearest hotel: The Sanctuary Hotel and Spa
# saipan - nearest hotel: Chalan Kanoa Beach Hotel
# berezovyy - nearest hotel: No hotel found
# pacific grove - nearest hotel: Pacific Grove Inn
# saint-tropez - nearest hotel: No hotel found
# douentza - nearest hotel: No hotel found
# egilsstadir - nearest hotel: Valaskjálf
# tura - nearest hotel: Hotel Polo Orchid
# sungai penuh - nearest hotel: Hotel Matahari
# lebu - nearest hotel: No hotel found
# luling - nearest hotel: Ramada by Wyndham Luling
# melfort - nearest hotel: No hotel found
# al musayyib - nearest hotel: عمارة الصفار
# namibe - nearest hotel: Nelsal Pensao
# recani - nearest hotel: Hotel Merzouga
# vilyuysk - nearest hotel: Мария
# krasnoarmeysk - nearest hotel: Гостиница
# les cayes - nearest hotel: No hotel found
# arteche - nearest hotel: No hotel found
# clearwater - nearest hotel: The Fort Harrison Hotel
# montorio - nearest hotel: Casa Rural Los Cazillos
# idri - nearest hotel: No hotel found
# palikir - national government center - nearest hotel: Mangrove Bay Hotel
# hotan - nearest hotel: Hua Yi International Hotel (accepts foreigners)
# tofol - nearest hotel: Nautilus Resort
# tazovsky - nearest hotel: Тазовчанка
# enewetak - nearest hotel: No hotel found
# zhoucun - nearest hotel: No hotel found
# nelidovo - nearest hotel: Центральная
# fort myers shores - nearest hotel: Comfort Inn Fort Myers
# jutai - nearest hotel: No hotel found
# vrangel' - nearest hotel: No hotel found
# papao - nearest hotel: Hiti Moana Villa Lodge
# nizhniy odes - nearest hotel: No hotel found
# troitsko-pechorsk - nearest hotel: Гостиница "Печора"
# newman - nearest hotel: No hotel found
# la'ie - nearest hotel: No hotel found
# shingu - nearest hotel: ホテルニューパレス
# ambovombe - nearest hotel: La source
# minas de marcona - nearest hotel: No hotel found
# toktogul - nearest hotel: No hotel found
# ierapetra - nearest hotel: No hotel found
# altinyayla - nearest hotel: No hotel found
# crane - nearest hotel: No hotel found
# timmins - nearest hotel: The Senator Hotel & Conference Centre
# naze - nearest hotel: ビジネス旅館畠山
# veraval - nearest hotel: Shyam
# salalah - nearest hotel: Muscat International Hotel
# colonia - nearest hotel: Wasserturm Hotel Cologne
# hasaki - nearest hotel: Choshi Plaza Hotel
# queenstown - nearest hotel: Queens Hotel
# devils lake - nearest hotel: Holiday Inn Express
# la sarre - nearest hotel: Motel le Bivouac
# bartonville - nearest hotel: Holiday Inn
# filingue - nearest hotel: Complexe Touristique de Kourfeye
# mejit - nearest hotel: No hotel found
# afaahiti - nearest hotel: Omati Lodge
# caleta de carquin - nearest hotel: Hotel Mi Choacan
# kudahuvadhoo - nearest hotel: Hotel Riu Palace Maldivas
# xinyuan - nearest hotel: No hotel found
# huancabamba - nearest hotel: Hostal Virgen del Carmen
# aksu - nearest hotel: Akesu Tianyuan International Hotel
# ambalangoda - nearest hotel: Hotel Italia
# roosevelt - nearest hotel: No hotel found
# hoima - nearest hotel: Hoima BUffalo Hotel
# bengkulu - nearest hotel: Dena Hotel
# brookings - nearest hotel: Quality Inn
# ancud - nearest hotel: Cabañas
# hawaiian paradise park - nearest hotel: No hotel found
# kodiak - nearest hotel: No hotel found
# dongning - nearest hotel: No hotel found
# ulladulla - nearest hotel: Hotel Marlin
# wad medani - nearest hotel: Allneel hotel
# manta - nearest hotel: Hotel Santa Fe
# kone - nearest hotel: Pacifik Appartels
# enriquillo - nearest hotel: Hotel Juan José
# ola - nearest hotel: No hotel found
# kyzylorda - nearest hotel: Нур
# happy valley-goose bay - nearest hotel: Hotel North Two
# constantia - nearest hotel: Hotel Chérica
# port saint john's - nearest hotel: Outback Inn
# trincomalee - nearest hotel: Summer set inn
# metahara - nearest hotel: Unique House
# remire-montjoly - nearest hotel: Complexe Belova
# forster - nearest hotel: No hotel found
# turochak - nearest hotel: Гостинница администрации
# campeni - nearest hotel: Hotel Cotul Arieșului
# labytnangi - nearest hotel: Семь лиственниц
# gantang - nearest hotel: No hotel found
# parham - nearest hotel: Oceanic View Exclusive Vacation Cottages
# st. john's - nearest hotel: Alt Hotel
# mizdah - nearest hotel: No hotel found
# acarau - nearest hotel: No hotel found
# severo-yeniseyskiy - nearest hotel: Актолик
# tamandare - nearest hotel: Pousada Baia dos Corais
# nolinsk - nearest hotel: No hotel found
# muar - nearest hotel: Hotel Leewa
# kirakira - nearest hotel: No hotel found
# taoudenni - nearest hotel: No hotel found
# nuevo ideal - nearest hotel: No hotel found
# ascension - nearest hotel: Cajun Country Inn
# shetpe - nearest hotel: Балумит
# hadibu - nearest hotel: No hotel found
# goure - nearest hotel: No hotel found
# pyay - nearest hotel: Yoma Royal
# east london - nearest hotel: No hotel found
# ciudad bolivar - nearest hotel: Paoca
# khost - nearest hotel: No hotel found
# port elizabeth - nearest hotel: Waterford Hotel
# labrador city - nearest hotel: Carol Inn
# yamada - nearest hotel: No hotel found
# puerto ayacucho - nearest hotel: Hotel VENETUR Amazonas
# san andres - nearest hotel: Hotel Decameron Isleño
# mana - nearest hotel: Le Samana
# mount gambier - nearest hotel: The Old Mount Gambier Gaol
# broken hill - nearest hotel: Ibis Styles
# jumla - nearest hotel: Amar Sandesh Guesthouse
# trairi - nearest hotel: Pousada Villa Aurora
# tabou - nearest hotel: hôtel le rochet
# jutiapa - nearest hotel: Mansión la villa
# noosa heads - nearest hotel: Costa Nova Apartments
# tawau - nearest hotel: Eden boutique
# sawakin - nearest hotel: Hotel Halfa
# reguiba - nearest hotel: No hotel found
# maintirano - nearest hotel: Hotel Safari
# aasiaat - nearest hotel: SØMA
# al burayqah - nearest hotel: فندق ماس ليبيا
# port alfred - nearest hotel: No hotel found
# tubarjal - nearest hotel: No hotel found
# aripuana - nearest hotel: No hotel found
# ga-rankuwa - nearest hotel: Dream Motel
# nueva loja - nearest hotel: Castillo Real
# trondheim - nearest hotel: Thon Hotel Trondheim
# hudson - nearest hotel: Ramada by Wyndham Jersey City
# baiti - nearest hotel: No hotel found
# sinop - nearest hotel: No hotel found
# hammerfest - nearest hotel: Thon Hotel Hammerfest
# vostochnyy - nearest hotel: Оранж
# novodvinsk - nearest hotel: Уют
# sanandaj - nearest hotel: هتل آبیدر
# afua - nearest hotel: No hotel found
# el alto - nearest hotel: No hotel found
# fortaleza - nearest hotel: Hotel Catedral
# bamboo flat - nearest hotel: Hotel Megapode Nest
# akhtubinsk - nearest hotel: Гостиница "Кулон"
# saint-philippe - nearest hotel: Le Baril
# dakhla - nearest hotel: Hotel El Massira
# lerwick - nearest hotel: Grand Hotel
# north side - nearest hotel: Novel
# turkmenbasy - nearest hotel: Hazar Myhmanhanasy
# pont rouge - nearest hotel: No hotel found
# new norfolk - nearest hotel: Woodbridge on the Derwent
# borskoye - nearest hotel: Элегия
# susuman - nearest hotel: No hotel found
# viedma - nearest hotel: Níjar
# puerto maldonado - nearest hotel: Puerto Palmeras
# qahderijan - nearest hotel: مرکز آموزشی رفاهی فرهنگیان نجف آباد
# lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# palmer - nearest hotel: No hotel found
# fuerte olimpo - nearest hotel: No hotel found
# tadine - nearest hotel: Hôtel Nengoné
# arenapolis - nearest hotel: No hotel found
# fort st. john - nearest hotel: Fort St. John Motor Inn
# vadso - nearest hotel: Scandic Vadsø
# margate - nearest hotel: The Reading Rooms
# lethem - nearest hotel: Hotel Amazonas
# gizo - nearest hotel: Gizo Hotel
# nykobing mors - nearest hotel: Steenbergs Hotel
# tambura - nearest hotel: No hotel found
# kingscliff - nearest hotel: Kingscliff Beach Hotel
# tateyama - nearest hotel: No hotel found
# thurso - nearest hotel: Station Hotel
# sao jose da coroa grande - nearest hotel: Hotel do Sol
# mirnyy - nearest hotel: Зарница
# sao gabriel da cachoeira - nearest hotel: Hotel Deus Me Deu
# teuva - nearest hotel: No hotel found
# mollendo - nearest hotel: Hostal California
# taltal - nearest hotel: Hostería Taltal
# casablanca - nearest hotel: Hotel de Prince de Paris
# asau - nearest hotel: Hotel Romanița
# holualoa - nearest hotel: Kona Hotel
# ciudad lazaro cardenas - nearest hotel: Hotel Sol del Pacífico
# zeya - nearest hotel: Серебряный створ
# tshikapa - nearest hotel: Hôtel TSHAMUNTU
# galle - nearest hotel: Jungle Hostel Villa
# sarnia - nearest hotel: The Insignia Hotel, Sarnia, a Tribute Portfolio Hotel
# mount isa - nearest hotel: Ibis Styles
# urjala - nearest hotel: Kylähotelli 1793
# stara tura - nearest hotel: Hotel Lipa
# korla - nearest hotel: Silver Star Hotel
# nkove - nearest hotel: No hotel found
# zaozersk - nearest hotel: Северное сияние
# nuuk - nearest hotel: Nordbo
# peniche - nearest hotel: Residencial Maciel
# pisco - nearest hotel: La Portada
# klaksvik - nearest hotel: Hotel Klaksvik
# torghay - nearest hotel: No hotel found
# cherokee - nearest hotel: Quality Inn & Suites Canton, Ga
# faya-largeau - nearest hotel: No hotel found
# coronel oviedo - nearest hotel: Duplex Paumar
# yichun - nearest hotel: No hotel found
# mount pearl - nearest hotel: Sandman Signature St. John's Hotel
# paracuru - nearest hotel: Vento Brasil
# fale old settlement - nearest hotel: No hotel found
# tavda - nearest hotel: No hotel found
# neiafu - nearest hotel: Port Wine Guest House
# vernon - nearest hotel: Okanagan Royal Park Inn
# usinsk - nearest hotel: общежитие Лукойл-Коми
# portland - nearest hotel: the Hoxton
# gonabad - nearest hotel: هتل پاسارگاد
# chonchi - nearest hotel: Hotel Huildín
# barra de santo antonio - nearest hotel: Resort Fazenda Fiore
# flying fish cove - nearest hotel: Christmas Island Lodge
# altinekin - nearest hotel: No hotel found
# tamale - nearest hotel: Alhassan Hotel
# kapuskasing - nearest hotel: Travelodge
# howrah - nearest hotel: Sun India Guest House
# petrolina - nearest hotel: Neuman
# kenai - nearest hotel: Beluga Lookout Hotel
# greymouth - nearest hotel: Recreation Hotel
# tekkali - nearest hotel: No hotel found
# katsuura - nearest hotel: 潮騒の宿
# la palma - nearest hotel: La Quinta Inn & Suites by Wyndham Buena Park
# cogealac - nearest hotel: No hotel found
# bako - nearest hotel: Goh Hotel
# sao tome - nearest hotel: Hotel Baia
# jiayuguan - nearest hotel: 嘉峪关宾馆
# gaiman - nearest hotel: yr hen ffordd
# oliva - nearest hotel: Azahar
# revda - nearest hotel: Металлург
# kapa'a - nearest hotel: Pono Kai Resort
# turbiv - nearest hotel: No hotel found
# uliastay - nearest hotel: Болоржин зочид буудал
# shchigry - nearest hotel: No hotel found
# katima mulilo - nearest hotel: Zambezi River Lodge
# timbuktu - nearest hotel: Hotel La Maison
# wenatchee - nearest hotel: Hilton Garden Inn
# bastrop - nearest hotel: No hotel found
# boca do acre - nearest hotel: No hotel found
# tataouine - nearest hotel: No hotel found
# bairnsdale - nearest hotel: Main hotel
# ormara - nearest hotel: No hotel found
# nuku'alofa - nearest hotel: City Hotel
# cachoeira do sul - nearest hotel: Hotel Jacuí
# priozersk - nearest hotel: Корела
# agios nikolaos - nearest hotel: No hotel found
# zamania - nearest hotel: No hotel found
# waingapu - nearest hotel: HOTEL SANDLEWOOD
# klyuchi - nearest hotel: No hotel found
# mahdia - nearest hotel: La Maison Bleue
# nova sintra - nearest hotel: Residência Ka Dencho
# santa maria da boa vista - nearest hotel: No hotel found
# kiunga - nearest hotel: No hotel found
# newbiggin-by-the-sea - nearest hotel: Premier Inn
# selfoss - nearest hotel: Miðgarður
# coquimbo - nearest hotel: Hotel Iberia
# bodo - nearest hotel: Zefyr hotell
# brezina - nearest hotel: No hotel found
# al kharijah - nearest hotel: Kharga Hotel
# jinchang - nearest hotel: No hotel found
# rampur - nearest hotel: تمنا ہوٹل اور ریستوران
# kralendijk - nearest hotel: Hotel Bonaire Inn
# permet - nearest hotel: Nako Guesthouse
# datca - nearest hotel: Marphe Hotel
# moyale - nearest hotel: Paul’s guest house
# solleftea - nearest hotel: Hotell Appelberg
# mutuali - nearest hotel: No hotel found
# jacksonville - nearest hotel: Hyatt Regency Jacksonville Riverfront
# ugoofaaru - nearest hotel: No hotel found
# maputsoe - nearest hotel: Sekekete Hotel
# chernyshevskiy - nearest hotel: No hotel found
# north saanich - nearest hotel: The Latch Inn & Restaurant
# bidur - nearest hotel: Loong Fatt Hotel
# prymors'k - nearest hotel: Ферросплавщик
# flin flon - nearest hotel: Copperbelt Hotel
# aral - nearest hotel: No hotel found
# sal rei - nearest hotel: Hotel Marine Club
# den burg - nearest hotel: De Lindeboom
# nabire - nearest hotel: Hotel Anggrek
# talara - nearest hotel: Hospedaje El Aypate
# atafu village - nearest hotel: No hotel found
# amursk - nearest hotel: Центральная
# demre - nearest hotel: Hotel Kekova
# cidade velha - nearest hotel: Encosta Azul
# poletayevo - nearest hotel: No hotel found
# north bend - nearest hotel: The Mill Casino Hotel
# harper - nearest hotel: No hotel found
# livingston - nearest hotel: Livingston Lodge Hotel
# buncrana - nearest hotel: Lake of Shadows Hotel
# filadelfia - nearest hotel: The Ritz-Carlton, Philadelphia
# merizo village - nearest hotel: No hotel found
# cesky tesin - nearest hotel: Hotel Central
# saudarkrokur - nearest hotel: Mikligarður
# puerto deseado - nearest hotel: Los Olmos
# ad dilam - nearest hotel: No hotel found
# aykhal - nearest hotel: Уют
# jitauna - nearest hotel: No hotel found
# yung shue wan - nearest hotel: 浪濤軒酒店 Concerto Inn
# sour el ghozlane - nearest hotel: No hotel found
# yuzhno-kurilsk - nearest hotel: Айсберг
# bria - nearest hotel: No hotel found
# likiep - nearest hotel: No hotel found
# anzio - nearest hotel: B&B Il Paradiso sul Mare
# tabas - nearest hotel: هتل امیر
# padang - nearest hotel: losmen Surya
# ilhabela - nearest hotel: Vila Kebaya
# la huacana - nearest hotel: No hotel found
# geraldton - nearest hotel: Ocean Centre Hotel
# funafuti - nearest hotel: Vaiaku Lagi Hotel
# santa ana - nearest hotel: Holiday Inn Express
# wisconsin rapids - nearest hotel: Hotel Mead
# sabang - nearest hotel: Sabang Hill
# kingston - nearest hotel: Aphrodite Hotel
# okha - nearest hotel: Сфера
# naivasha - nearest hotel: Supa Lodge
# orumiyeh - nearest hotel: هتل لاله
# playa vicente - nearest hotel: No hotel found
# uvinza - nearest hotel: Mapito lodge
# merowe - nearest hotel: Merowe Land
# reggane - nearest hotel: No hotel found
# bolivar - nearest hotel: Best Western Plus
# madera - nearest hotel: No hotel found
# lagos - nearest hotel: No hotel found
# sanya - nearest hotel: Хубаёши
# cameron - nearest hotel: Deluxe 6 Inn & Suites
# nemuro - nearest hotel: お宿エクハシ
# shamva - nearest hotel: No hotel found
# tongouson - nearest hotel: No hotel found
# kpandae - nearest hotel: Bowmarie Resort
# gadzhiyevo - nearest hotel: Оазис
# nambucca heads - nearest hotel: Star Hotel
# borogontsy - nearest hotel: No hotel found
# akjoujt - nearest hotel: Hotel Fatima فندق فاطمة
# kodinsk - nearest hotel: Ангара
# dunedin - nearest hotel: Scenic Hotel Dunedin City
# puerto baquerizo moreno - nearest hotel: Dory's House
# saint-joseph - nearest hotel: PALM Hotel & Spa
# mossel bay - nearest hotel: Protea Hotel Mossel Bay
# sharkawshchyna - nearest hotel: No hotel found
# vysokiy - nearest hotel: Орион
# chintamani - nearest hotel: No hotel found
# prince rupert - nearest hotel: Crest Hotel
# amga - nearest hotel: "АммА"
# toliara - nearest hotel: Ambary
# sejenane - nearest hotel: No hotel found
# kotlas - nearest hotel: Советская
# lamu - nearest hotel: Hotel Archipelago villa bed and breakfast
# boende - nearest hotel: Hotel Reference
# minokamo - nearest hotel: ルートイン美濃加茂
# roma - nearest hotel: Wingate by Wyndham Rome
# ma'ili - nearest hotel: No hotel found
# saint-denis - nearest hotel: Tribe
# cidreira - nearest hotel: Hotel Castelo
# hilo - nearest hotel: Dolphin Bay Hotel
# essaouira - nearest hotel: Essaouira Wind Palace
# muynoq - nearest hotel: Lala
# maydanshakhr - nearest hotel: No hotel found
# wapi pathum - nearest hotel: No hotel found
# onverwacht - nearest hotel: B&B Banabeki
#                 City Country      Lat       Lng  Humidity    Hotel Name
# 0          vorgashor      RU  67.5833   63.9500        96         София
# 1      blackmans bay      AU -43.0167  147.3167        86  Villa Howden
# 2  port-aux-francais      TF -49.3500   70.2167        95       Keravel
# 3            talnakh      RU  69.4865   88.3972        98        Талнах
# 4            dudinka      RU  69.4058   86.1778        94      Виктория

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
  # Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng", 
    "Lat", 
    geo=True,
    color="City",
    size="Humidity",
    tiles="OSM",
    hover_cols=["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
